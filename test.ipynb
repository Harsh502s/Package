# %%
import pandas as pd
from Astras.Agniastra import regression_model_comparison

df = pd.read_csv(r"C:\Users\ds12\College\ML-Assignments\Data Sets\MLK\cleanusa.csv")

df.head()

X = df.drop("Price", axis=1)
y = df["Price"]

# %%
regression_model_comparison(X,y)
# Out:
#                    Train Score  Test Score             MSE       MAE  \
# Ridge Regression          0.90        0.90  11397823291.86  85380.42
# Lasso Regression          0.90        0.90  11398039198.99  85381.49
# Linear Regression         0.90        0.90  11398052055.31  85381.58
# CatBoost                  0.94        0.89  12319061925.19  89652.44
# Random Forest             0.98        0.87  15341127008.86  99757.56
# XGBoost                   0.97        0.87  15368326571.08 100017.17
# Decision Tree             1.00        0.74  29953333357.49 140212.22
# KNN                       0.65        0.52  55638605594.67 190162.70
# SVR                       0.00        0.00 116406629128.54 274697.11
#
#                        RMSE  R2 Score
# Ridge Regression  106760.59      0.90
# Lasso Regression  106761.60      0.90
# Linear Regression 106761.66      0.90
# CatBoost          110991.27      0.89
# Random Forest     123859.30      0.87
# XGBoost           123969.05      0.87
# ...

# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier

df = pd.read_csv(r"C:\Users\ds12\College\ML-Assignments\Data Sets\MLK\diabetes.csv")

df.head()

X = df.drop("Outcome", axis=1)
y = df["Outcome"]

from Astras.Brahmastra import classification_model_comparison,report_print

# %%
classification_model_comparison(X,y,scaling="ss")
# Out:
#      Train Score  Test Score  Accuracy Score  ROC AUC Score  F1 Score  \
# LR          0.77        0.78            0.78           0.74      0.66
# CB          0.96        0.76            0.76           0.73      0.66
# GNB         0.77        0.74            0.74           0.71      0.64
# RFC         1.00        0.73            0.73           0.70      0.60
# KNN         0.79        0.72            0.72           0.70      0.61
# SVM         0.77        0.73            0.73           0.68      0.58
# XGB         1.00        0.71            0.71           0.68      0.59
# DT          1.00        0.67            0.67           0.66      0.58
# BNB         0.66        0.62            0.62           0.50      0.00
#
#      Precision Score  Recall Score
# LR              0.75          0.59
# CB              0.68          0.63
# GNB             0.66          0.62
# RFC             0.67          0.55
# KNN             0.62          0.61
# SVM             0.70          0.49
# ...

# %%
report_print('LR',X,y)
# Out:
# Model Name: LR
# Classification Report for
#               precision    recall  f1-score   support
#
#            0       0.78      0.94      0.86       125
#            1       0.83      0.51      0.63        67
#
#     accuracy                           0.79       192
#    macro avg       0.81      0.73      0.74       192
# weighted avg       0.80      0.79      0.78       192

# %%
report_print('DT',X,y)
# Out:
# Model Name: DT
# Classification Report for
#               precision    recall  f1-score   support
#
#            0       0.77      0.76      0.77       125
#            1       0.57      0.58      0.57        67
#
#     accuracy                           0.70       192
#    macro avg       0.67      0.67      0.67       192
# weighted avg       0.70      0.70      0.70       192

# %%
report_print('RFC',X,y)
# Out:
# Model Name: RFC
# Classification Report for
#               precision    recall  f1-score   support
#
#            0       0.79      0.90      0.84       125
#            1       0.76      0.55      0.64        67
#
#     accuracy                           0.78       192
#    macro avg       0.77      0.73      0.74       192
# weighted avg       0.78      0.78      0.77       192

# %%
import setuptools

setuptools.find_packages()
# Out:
# ['Astras']
